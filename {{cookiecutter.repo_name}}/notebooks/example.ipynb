# %%
import sys
sys.path.insert(0, '..')

# %%
ls ~/.nussl/cache

# %%
from cookiecutter_repo import dataset
import os
from runners.utils import load_yaml

spec = load_yaml('../experiments/speech_dpcl.yml')
DatasetClass = getattr(dataset, spec['datasets']['train']['class'])
folder = spec['datasets']['train']['folder']
spec['dataset_config']['cache'] = None # so it caches only in this container
spec['dataset_config']['overwrite_cache'] = True

dset = DatasetClass(folder, spec['dataset_config'])
dset.inspect(0)
# Out:
# AudioSignal (unlabeled): 1 ch, 5.0 sec @ /home/data//babywsj8k/generated/train/00000562.wav
# [<nussl.core.audio_signal.AudioSignal object at 0x7f2efa480b70>, <nussl.core.audio_signal.AudioSignal object at 0x7f2efa480e48>]
# [[1. 0.]
#  [0. 1.]]
# Mixture + original sources
#                 <audio controls="controls" >
#                     <source src="data:audio/mpeg;base64,..." type="audio/mpeg" />
#                     Your browser does not support the audio element.
#                 </audio>
#                 <audio controls="controls" >
#                     <source src="data:audio/mpeg;base64,..." type="audio/mpeg" />
#                     Your browser does not support the audio element.
#                 </audio>
#                 <audio controls="controls" >
#                     <source src="data:audio/mpeg;base64,..." type="audio/mpeg" />
#                     Your browser does not support the audio element.
#                 </audio>
# Sources masked from mixture
# ...
