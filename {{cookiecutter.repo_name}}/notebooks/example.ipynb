# %%
import sys
sys.path.insert(0, '..')

# %%
from cookiecutter_repo.dataset import Scaper
import os
from runners.utils import load_yaml

folder = os.path.join(os.getenv('DATA_DIRECTORY'), 'musdb/generated/incoherent/train')
spec = load_yaml('../experiments/speech_dpcl.yml')
spec['dataset_config']['cache'] = '~/.nussl/cache' # so it caches only in this container
spec['dataset_config']['sample_rate'] = 16000
spec['dataset_config']['group_sources'] = [['drums', 'bass', 'other']]
dset = Scaper(folder, spec['dataset_config'])
dset.inspect(0)
# Out:
# 2019-11-30:12:00:37,42 INFO     [base_dataset.py:83] Caching to: /home/pseetharaman/.nussl/cache/_home_data_musdb_generated_incoherent_train/default.zarr
# 2019-11-30:12:00:37,44 INFO     [base_dataset.py:87] Cache location /home/pseetharaman/.nussl/cache/_home_data_musdb_generated_incoherent_train/default.zarr exists! Checking if overwrite. Otherwise, will use cache.
# AudioSignal (unlabeled): 1 ch, 10.0 sec @ /home/data/musdb/generated/incoherent/train/00000030.wav
# [<nussl.core.audio_signal.AudioSignal object at 0x7f3f4986f5c0>, <nussl.core.audio_signal.AudioSignal object at 0x7f3f4c17d978>]
# [[0. 0. 0. 1. 0.]
#  [0. 0. 0. 0. 1.]]
# Mixture + original sources
#                 <audio controls="controls" >
#                     <source src="data:audio/mpeg;base64,..." type="audio/mpeg" />
#                     Your browser does not support the audio element.
#                 </audio>
#                 <audio controls="controls" >
# ...
