# %%
import sys
sys.path.insert(0, '..')

# %%
from cookiecutter_repo.dataset import Scaper
import os
from runners.utils import load_yaml

folder = os.path.join(os.getenv('DATA_DIRECTORY'), 'babywsj8k/generated/train')
spec = load_yaml('../experiments/train.yml')
spec['dataset_config']['cache'] = '~/.nussl/cache' # so it caches only in this container
dset = Scaper(folder, spec['dataset_config'])
dset.inspect(0)
# Out:
# 2019-11-25:02:35:18,339 INFO     [base_dataset.py:83] Caching to: /home/prem/.nussl/cache/_media_hdd_3tb_datasets_babywsj8k_generated_train/default.zarr
# 2019-11-25:02:35:18,340 INFO     [base_dataset.py:87] Cache location /home/prem/.nussl/cache/_media_hdd_3tb_datasets_babywsj8k_generated_train/default.zarr exists! Checking if overwrite. Otherwise, will use cache.
# AudioSignal (unlabeled): 1 ch, 5.0 sec @ /media/hdd_3tb/datasets/babywsj8k/generated/train/00001193.wav
# [<nussl.core.audio_signal.AudioSignal object at 0x7fce171dc710>, <nussl.core.audio_signal.AudioSignal object at 0x7fce171e9b38>]
# [[1. 0.]
#  [0. 1.]]
# Mixture + original sources
#                 <audio controls="controls" >
#                     <source src="data:audio/mpeg;base64,..." type="audio/mpeg" />
#                     Your browser does not support the audio element.
#                 </audio>
#                 <audio controls="controls" >
#                     <source src="data:audio/mpeg;base64,..." type="audio/mpeg" />
#                     Your browser does not support the audio element.
#                 </audio>
#                 <audio controls="controls" >
#                     <source src="data:audio/mpeg;base64,..." type="audio/mpeg" />
#                     Your browser does not support the audio element.
#                 </audio>
# Sources masked from mixture
#                 <audio controls="controls" >
#                     <source src="data:audio/mpeg;base64,..." type="audio/mpeg" />
#                     Your browser does not support the audio element.
#                 </audio>
#                 <audio controls="controls" >
#                     <source src="data:audio/mpeg;base64,..." type="audio/mpeg" />
#                     Your browser does not support the audio element.
#                 </audio>
